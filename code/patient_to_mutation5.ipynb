# %%
import pandas as pd

data = pd.read_excel("../data/Genomics/Genomics_5.xlsx", sheet_name='All Out')
final = pd.read_excel("../data/Genomics/Genomics_5.xlsx", sheet_name='Final')

# %%
list(data.columns)
# Out:
# ['Chromosome',
#  'Position',
#  'Reference Allele',
#  'Sample Allele',
#  'Variation Type',
#  'Gene Region',
#  'Gene Symbol',
#  'Transcript ID',
#  'Transcript Variant',
#  'Protein Variant',
#  'Variant Findings',
#  'Case Samples With Variant',
#  'Final Call',
#  '28336_Heme_D4_CH23129-1249T_S100_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
#  '28336_Heme_B3_CH21381-0871S_S90_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
#  '28336_Heme_A6_CH24844-0376EB_S113_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
#  '28336_Heme_A5_CH24282-0763EB_S105_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
#  '28336_Heme_B1_CH16887-0544EB_S74_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
#  '28336_Heme_B2_CH20786-0435EB_S82_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
#  '28336_Heme_A4_CH23129-1249B_S97_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
#  '28336_Heme_A3_CH21381-0871EB_S89_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
# ...

# %%
### table 1
data[['Chromosome',
 'Position',
 'Reference Allele',
 'Sample Allele',
 'Variation Type',
 'Gene Region',
 'Gene Symbol',
 'Transcript ID',
 'Transcript Variant',
 'Protein Variant' ]]
# Out:
#       Chromosome   Position Reference Allele Sample Allele Variation Type  \
# 0             17    7578406                C             T            SNV
# 1             17    7577120                C             T            SNV
# 2             17    7577539                G             A            SNV
# 3             17    7577538                C             T            SNV
# 4             17    7577121                G             A            SNV
# ...          ...        ...              ...           ...            ...
# 53252          X  154005091                G             A            SNV
# 53253          6  144461946                A             G            SNV
# 53254         10   27284064                C             A            SNV
# 53255         10   27284066                T             G            SNV
# 53256         10   27284076                C             A            SNV
#
#                 Gene Region Gene Symbol  \
# ...

# %%
data["Reference Allele"] = data["Reference Allele"].fillna('X')
data['Sample Allele'] = data['Sample Allele'].fillna('X')

# %%
table2_1 = data[['Chromosome',
 'Position','Reference Allele','Sample Allele','Classification','28336_Heme_D4_CH23129-1249T_S100_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_B3_CH21381-0871S_S90_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_A6_CH24844-0376EB_S113_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_A5_CH24282-0763EB_S105_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_B1_CH16887-0544EB_S74_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_B2_CH20786-0435EB_S82_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_A4_CH23129-1249B_S97_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_A3_CH21381-0871EB_S89_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_H6_CH23638-0174T_S120_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_H5_CH24844-0376B_S112_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_A2_CH20785-0172T_S81_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_A1_CH13176-0771EB_S73_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_H2_CH21285-1162T_S88_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_H3_CH22195-0582EB_S96_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_H4_CH24282-0763B_S104_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_G6_CH23638-0174N_S119_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_H1_CH20596-1151N_S80_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_G5_CH24580-1283S_S111_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_G4_CH24080-0863EB_S103_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_G3_CH22195-0582B_S95_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_F5_CH24580-1283EB_S110_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_G1_CH20596-1151S_S79_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_F3_24936-0658T_S94_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_G2_CH21285-1162N_S87_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_F4_CH24080-0863B_S102_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_F2_CH21285-1162EB_S86_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_F6_CH23638-0174EB_S118_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_F1_CH18161-0756EB_S78_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_E4_CH23253-0960N_S101_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_E6_CH23638-0174B_S117_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_E5_CH24580-1283B_S109_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_E3_24936-0658N_S93_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_E2_CH21285-1162B_S85_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_D2_24775-0856T_S84_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_B4_CH23129-1249EB_S98_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_E1_CH17690-0777B_S77_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_D6_CH24844-0376T_S116_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_D5_CH24282-0763N_S108_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_D3_CH21726-0658EB_S92_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme_D1_CH17614-0387EB_S76_L999_R1_001_(paired)Unfiltered_Variants - Genotype',
 '28336_Heme
#  'chr15:34635255_A-->T',
#  'chr15:34635261_T-->A',
#  'chr15:34635245_C-->T',
#  'chr10:43614996_G-->C',
#  'chr15:34635232_A-->G',
#  'chr15:34635232_A-->T',
#  'chr15:34635236_T-->C',
#  'chr15:34635228_G-->A',
#  'chr1:27023220_C-->T',
#  'chr1:27023282_G-->A',
#  'chr4:153247366_C-->T',
#  'chr20:57484421_G-->A',
#  'chr2:48030639_X-->C',
#  'chr17:41215947_C-->T',
#  'chr20:57484420_C-->T',
#  'chr17:74733244_G-->T',
#  'chr17:74733246_T-->A',
#  'chr13:32930609_C-->T',
# ...

# %%
table2_1 = table2_1.set_index('Mutation_ID')

# %%
final["Reference Allele"] = final["Reference Allele"].fillna('X')
final['Sample Allele'] = final['Sample Allele'].fillna('X')

# %% [markdown]
# Data Cleaning rules:
#
# Clean up string: startwith P - Pathogenic; start with LP or Likely P -> Likely Pathogenic; startwith U - Uncertain Significance; startswith B - Benign; startswith Likely B or LB -> Likely Benign

# %%
def cleansing(text):
    if text.startswith("P") == True:
        return "Pathogenic"
    elif text.startswith("LP") == True or text.startswith("Likely P") == True:
        return "Likely Pathogenic"
    elif text.startswith("U") == True:
        return "Uncertain Significance"
    elif text.startswith("B") == True:
        return "Benign"
    elif text.startswith("LB") == True or text.startswith("Likely B") == True:
        return "Likely Benign"
    else:
        print("Error")
        print(text)
        return text

# %%
final["Final Call"] = final["Final Call"].apply(lambda x : cleansing(x))

final["Mutation_ID"] ='chr'+ final["Chromosome"].astype(str) + ':' + final["Position"].astype(str) +"_" + final['Reference Allele']+'-->'+final['Sample Allele']
table2_1["curated"] = "No"
final["curated"] = "Yes"               

change = final[["Mutation_ID","Final Call", "curated"]]

change_dict = change.set_index('Mutation_ID').to_dict()['Final Call']
change_dict_2 = change.set_index('Mutation_ID').to_dict()["curated"]
change_dict
# table2_1 = table2_1.replace(change_dict)


for mutation_ID in change_dict.keys():
#     table2_1[table2_1.Mutation_ID == mutation_ID]["Classification"] = change_dict[mutation_ID]
    table2_1.loc[mutation_ID,"Classification"] = change_dict[mutation_ID]
    table2_1.loc[mutation_ID,"curated"] = change_dict_2[mutation_ID]

# %%
name_field = list(table2_1.columns)

# %%
name_field_1 = name_field[:5]
patient_list = []
for i in name_field[5:-1]:
#     print(i)
    patient_id = i.split("_")[3]
    data_name = i.split("-")[-1]
    patient_list.append(patient_id)
    name_field_1.append(patient_id+data_name)
patient_list = set(patient_list)
len(patient_list)
# Out:
# 48

# %%
table2_1.T
# Out:
# Mutation_ID                                        chr17:7578406_C-->T  \
# Chromosome                                                          17
# Position                                                       7578406
# Reference Allele                                                     C
# Sample Allele                                                        T
# Classification                                              Pathogenic
# ...                                                                ...
# 28336_Heme_C1_CH16887-0544T_S75_L999_R1_001_(pa...                 NaN
# 28336_Heme_C3_CH25169-0263B_S91_L999_R1_001_(pa...                 NaN
# 28336_Heme_C2_24752-1184T_S83_L999_R1_001_(pair...                6.06
# 28336_Heme_B5_CH24282-0763S_S106_L999_R1_001_(p...                 NaN
# curated                                                            Yes
#
# Mutation_ID                                        chr17:7577120_C-->T  \
# ...

# %%
name_dict = {}
for i in range(len(name_field_1)):
    name_dict[name_field[i]] = name_field_1[i]

# %%
table2_1 = table2_1.rename(columns = name_dict, inplace = False)

# %%
table2_1
# Out:
#                      Chromosome   Position Reference Allele Sample Allele  \
# Mutation_ID
# chr17:7578406_C-->T          17    7578406                C             T
# chr17:7577120_C-->T          17    7577120                C             T
# chr17:7577539_G-->A          17    7577539                G             A
# chr17:7577538_C-->T          17    7577538                C             T
# chr17:7577121_G-->A          17    7577121                G             A
# ...                         ...        ...              ...           ...
# chrX:154005091_G-->A          X  154005091                G             A
# chr6:144461946_A-->G          6  144461946                A             G
# chr10:27284064_C-->A         10   27284064                C             A
# chr10:27284066_T-->G         10   27284066                T             G
# chr10:27284076_C-->A         10   27284076                C             A
#
# ...

# %%
df = pd.DataFrame()
from tqdm import tqdm
for patient_id in tqdm(patient_list):
    mutation_list = list(table2_1[patient_id+" Genotype"][~table2_1[patient_id+" Genotype"].isna()].index)
    
    new_dict ={}
    for mutation in mutation_list:
        tmp = table2_1.loc[mutation][[patient_id+" Genotype",patient_id+" Compound Heterozygous",patient_id+" Read Depth",patient_id+" Allele Fraction",'Classification', "curated"]]
        
        row = {"Mutation_id" : mutation, "Lab UPN" : patient_id,"Genotype": tmp[0], "Compound Heterozygous" : tmp[1], "Read Depth" : tmp[2], "Allele Fraction" : tmp[3],"Classification" : tmp[4], "Curated" : tmp[5]}
        df = df.append(row, ignore_index = True)
# Out:
# 100%|██████████| 48/48 [11:37<00:00, 14.52s/it]

# %% [markdown]
# patient_id :
#     mutation :
#         [mutation1 :
#                 [1]
#                 [2]
#                 [3]
#                 [4],
#                 benign or not
#          mutation2 :
#                  [1]
#                  [2]
#                  [3]
#                  [4]
#                  ]

# %%
df = df.set_index(['Mutation_id'])

# %%
df.to_csv('../output/patient_to_mutation_5.csv', index=True)

# %%
import pandas as pd
df = pd.read_csv('../output/patient_to_mutation_5.csv')

# %%
df = df.rename(columns={"Allele Fraction" : "Allele_Fraction", "Compound Heterozygous" : "Compound_Heterozygous", "Lab UPN": "Lab_UPN", "Read Depth":"Read_Depth"})

# %%
df["Lab_UPN"] = df["Lab_UPN"].apply(lambda x : x[:12])

# %%
def ftn(x):
    if x.startswith("CH") == False:
        x = 'CH'+x
    list1 = x.split('-')
    x = list1[0]+'-'+list1[1][:4]
    return x

# %%
df["Lab_UPN"] = df["Lab_UPN"].apply(lambda x : ftn(x))

# %%
df["Lab_UPN"].unique()
# Out:
# array(['CH22195-0582', 'CH23638-0174', 'CH24844-0376', 'CH17614-0387',
#        'CH25169-0263', 'CH24282-0763', 'CH24580-1283', 'CH24936-0658',
#        'CH23129-1249', 'CH16887-0544', 'CH24775-0856', 'CH20786-0435',
#        'CH20596-1151', 'CH21285-1162', 'CH21726-0658', 'CH17690-0777',
#        'CH18161-0756', 'CH24080-0863', 'CH21381-0871', 'CH20785-0172',
#        'CH24752-1184', 'CH13176-0771', 'CH23253-0960'], dtype=object)

# %%
df.to_csv('../output/patient_to_mutation_5.csv', index=True)

# %%
# Import dataframe into MySQL
import sqlalchemy
database_username = 'root'
database_password = 'Kjy11422@'
database_ip       = '127.0.0.1'
database_name     = 'Genomics'
database_connection = sqlalchemy.create_engine('mysql+mysqlconnector://{0}:{1}@{2}/{3}'.
                                               format(database_username, database_password, 
                                                      database_ip, database_name))
df.to_sql(con=database_connection, name='Genomics_5', if_exists='replace')
