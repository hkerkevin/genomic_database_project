L999_R1_001_(paired)Unfiltered_Variants - Allele Fraction',
 '28337_Carrier_E11_MX25383-0477_S157_L999_R1_001_(paired)Unfiltered_Variants - Allele Fraction',
 '28337_Carrier_E7_CO22344-0275_S125_L999_R1_001_(paired)Unfiltered_Variants - Allele Fraction',
 '28337_Carrier_E9_CO23881-0178_S141_L999_R1_001_(paired)Unfiltered_Variants - Allele Fraction',
 '28337_Carrier_D12_MX25400-0173_S164_L999_R1_001_(paired)Unfiltered_Variants - Allele Fraction',
 '28337_Carrier_E8_CO23871-1172_S133_L999_R1_001_(paired)Unfiltered_Variants - Allele Fraction',
 '28337_Carrier_D11_MX25381-0159_S156_L999_R1_001_(paired)Unfiltered_Variants - Allele Fraction',
 '28337_Carrier_D9_CO23880-0736_S140_L999_R1_001_(paired)Unfiltered_Variants - Allele Fraction',
 '28337_Carrier_D10_MX24179-1076_S148_L999_R1_001_(paired)Unfiltered_Variants - Allele Fraction',
 '28337_Carrier_C11_MX25379-1238_S155_L999_R1_001_(paired)Unfiltered_Variants - Allele Fraction',
 '28337_Carrier_D7_AB22152-0540_S124_L999_R1_001_(paired)Unfiltered_Variants - Allele Fraction',
 '28337_Carrier_D8_CO23870-1046_S132_L999_R1_001_(paired)Unfiltered_Variants - Allele Fraction',
 '28337_Carrier_C10_CO23887-0674_S147_L999_R1_001_(paired)Unfiltered_Variants - Allele Fraction',
 '28337_Carrier_C12_MX25399-0472_S163_L999_R1_001_(paired)Unfiltered_Variants - Allele Fraction',
 '28337_Carrier_C9_CO23879-1159_S139_L999_R1_001_(paired)Unfiltered_Variants - Allele Fraction',
 '28337_Carrier_C8_CO23868-1084_S131_L999_R1_001_(paired)Unfiltered_Variants - Allele Fraction',
 '28337_Carrier_C7_JH20564-0855_S123_L999_R1_001_(paired)Unfiltered_Variants - Allele Fraction',
 '28337_Carrier_B11_MX25374-0569_S154_L999_R1_001_(paired)Unfiltered_Variants - Allele Fraction',
 '28337_Carrier_B12_MX25398-0269_S162_L999_R1_001_(paired)Unfiltered_Variants - Allele Fraction']]

# %%
##Foreign Key from mutation_information with Chromosome, position, reference Allele and Sample Allele
table2_1["Mutation_ID"] ='chr'+ table2_1["Chromosome"].astype(str) + ':' + table2_1["Position"].astype(str) +"_" + table2_1['Reference Allele']+'-->'+table2_1['Sample Allele']

# %%
Index = table2_1["Mutation_ID"]

# %%
list(table2_1["Mutation_ID"])[:5]
# Out:
# ['chr1:10566192_C-->T',
#  'chr1:10566196_T-->C',
#  'chr1:10566205_A-->G',
#  'chr1:10566210_C-->A',
#  'chr1:10566215_A-->G']

# %%
table2_1 = table2_1.set_index('Mutation_ID')

# %%
final = pd.read_excel("../data/Genomics/Genomics_1.xlsx", sheet_name='Final')
final["Reference Allele"] = final["Reference Allele"].fillna('X')
final['Sample Allele'] = final['Sample Allele'].fillna('X')

# %% [markdown]
# Data Cleaning rules:
#
# Clean up string: startwith P - Pathogenic; start with LP or Likely P -> Likely Pathogenic; startwith U - Uncertain Significance; startswith B - Benign; startswith Likely B or LB -> Likely Benign

# %%
def cleansing(text):
    if text.startswith("P") == True:
        return "Pathogenic"
    elif text.startswith("LP") == True or text.startswith("Likely P") == True:
        return "Likely Pathogenic"
    elif text.startswith("U") == True:
        return "Uncertain Significance"
    elif text.startswith("B") == True:
        return "Benign"
    elif text.startswith("LB") == True or text.startswith("Likely B") == True:
        return "Likely Benign"
    else:
        print("Error")
        print(text)
        return text

# %%
### replace some rows All out sheet with final sheet
final["Final Call"] = final["Final Call"].apply(lambda x : cleansing(x))

final["Mutation_ID"] ='chr'+ final["Chromosome"].astype(str) + ':' + final["Position"].astype(str) +"_" + final['Reference Allele']+'-->'+final['Sample Allele']
table2_1["curated"] = "No"
final["curated"] = "Yes"               

change = final[["Mutation_ID","Final Call", "curated"]]

change_dict = change.set_index('Mutation_ID').to_dict()['Final Call']
change_dict_2 = change.set_index('Mutation_ID').to_dict()["curated"]
change_dict
# table2_1 = table2_1.replace(change_dict)


for mutation_ID in change_dict.keys():
#     table2_1[table2_1.Mutation_ID == mutation_ID]["Classification"] = change_dict[mutation_ID]
    table2_1.loc[mutation_ID,"Classification"] = change_dict[mutation_ID]
    table2_1.loc[mutation_ID,"curated"] = change_dict_2[mutation_ID]

# %%
name_field = list(table2_1.columns)

# %%
name_field_1 = name_field[:5]
patient_list = []
for i in name_field[5:-1]:
#     print(i)
    patient_id = i.split("_")[3]
    data_name = i.split("-")[-1]
    patient_list.append(patient_id)
    name_field_1.append(patient_id+data_name)
patient_list = set(patient_list)
len(patient_list)
# Out:
# 48

# %%
table2_1.T
# Out:
# Mutation_ID                                            chr1:10566192_C-->T  \
# Chromosome                                                               1
# Position                                                          10566192
# Reference Allele                                                         C
# Sample Allele                                                            T
# Classification                                      Uncertain Significance
# ...                                                                    ...
# 28337_Carrier_C8_CO23868-1084_S131_L999_R1_001_...                     NaN
# 28337_Carrier_C7_JH20564-0855_S123_L999_R1_001_...                     NaN
# 28337_Carrier_B11_MX25374-0569_S154_L999_R1_001...                     NaN
# 28337_Carrier_B12_MX25398-0269_S162_L999_R1_001...                     NaN
# curated                                                                 No
#
# ...

# %%
name_dict = {}
for i in range(len(name_field_1)):
    name_dict[name_field[i]] = name_field_1[i]

# %%
table2_1 = table2_1.rename(columns = name_dict, inplace = False)

# %%
final_json = {}
for patient_id in patient_list:
    mutation_list = list(table2_1[patient_id+" Genotype"][~table2_1[patient_id+" Genotype"].isna()].index)
    final_json[patient_id] = []
    new_dict ={}
    for mutation in mutation_list:
        tmp = table2_1.loc[mutation][[patient_id+" Genotype",patient_id+" Compound Heterozygous",patient_id+" Read Depth",patient_id+" Allele Fraction",'Classification', "curated"]]
        
        new_dict[mutation] = {"Genotype": tmp[0], "Compound Heterozygous" : tmp[1], "Read Depth" : tmp[2], "Allele Fraction" : tmp[3],"Classification" : tmp[4], "Curated" : tmp[5]}
    final_json[patient_id] = new_dict

# %%
final_json['MX25394-1075']['chr1:10566215_A-->G']
# Out:
# {'Genotype': 'Het',
#  'Compound Heterozygous': 'No',
#  'Read Depth': 128.0,
#  'Allele Fraction': 50.0,
#  'Classification': 'Benign',
#  'Curated': 'No'}

# %% [markdown]
# patient_id :
#     mutation :
#         [mutation1 :
#                 [1]
#                 [2]
#                 [3]
#                 [4],
#                 benign or not
#          mutation2 :
#                  [1]
#                  [2]
#                  [3]
#                  [4]
#                  ]

# %%
## final ljson to dataframe
from tqdm import tqdm
df = pd.DataFrame()
for patient_id in list(final_json.keys()):
    mutation  = final_json[patient_id]
    for mutation_id in tqdm(mutation.keys()):
#         print(mutation[mutation_id])
        row = mutation[mutation_id]
        data = {'Lab UPN': patient_id, 'Mutation_id' : mutation_id}
#         print(row)
#         print(data)
        data.update(row)
        df = df.append(data, ignore_index=True)
# Out:
# ...
# 100%|██████████| 1156/1156 [00:08<00:00, 135.67it/s]
# 0it [00:00, ?it/s]
# ...
# 100%|██████████| 1159/1159 [00:10<00:00, 108.81it/s]

# %%
df = df.set_index(['Mutation_id'])

# %%
df.to_csv('../output/patient_to_mutation_1.csv', index=True)

# %%
import pandas as pd
df = pd.read_csv('../output/patient_to_mutation_1.csv')

# %%
df = df.rename(columns={"Allele Fraction" : "Allele_Fraction", "Compound Heterozygous" : "Compound_Heterozygous", "Lab UPN": "Lab_UPN", "Read Depth":"Read_Depth"})

# %%
df
# Out:
#                  Mutation_id  Allele_Fraction          Classification  \
# 0        chr1:10566230_C-->A             2.67  Uncertain Significance
# 1        chr1:10566272_C-->T            51.98                  Benign
# 2        chr1:45797154_G-->A             2.02  Uncertain Significance
# 3        chr1:45797505_C-->G            47.12                  Benign
# 4        chr1:45797951_G-->X             0.81       Likely Pathogenic
# ...                      ...              ...                     ...
# 56425   chr22:40876274_G-->T            14.89  Uncertain Significance
# 56426   chr22:40876278_X-->T             7.45                  Benign
# 56427   chr22:40876278_A-->T             7.45  Uncertain Significance
# 56428   chr22:40876279_T-->X            17.02  Uncertain Significance
# 56429  chr22:40876279_TT-->X             5.32  Uncertain Significance
#
#       Compound_Heterozygous Curated Genotype       Lab_UPN  Read_Depth
# ...

# %%
df.to_csv('../output/patient_to_mutation_1.csv', index=True)

# %%
# Import dataframe into MySQL
import sqlalchemy
database_username = 'root'
database_password = 'Kjy11422@'
database_ip       = '127.0.0.1'
database_name     = 'Genomics'
database_connection = sqlalchemy.create_engine('mysql+mysqlconnector://{0}:{1}@{2}/{3}'.
                                               format(database_username, database_password, 
                                                      database_ip, database_name))
df.to_sql(con=database_connection, name='Genomics_1', if_exists='replace')
